# %%
import pandas as pd
uber_data=pd.read_csv("Uber.csv")
uber_data.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
uber_data
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
print(uber_data.shape)
# Out:
# (1156, 7)

# %%
print(uber_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1156 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB
# None

# %%
print(uber_data.describe())
# Out:
#              MILES*
# count   1156.000000
# mean      21.115398
# std      359.299007
# min        0.500000
# 25%        2.900000
# 50%        6.000000
# 75%       10.400000
# max    12204.700000

# %%
print(uber_data.isnull().sum())
# Out:
# START_DATE*      0
# END_DATE*        1
# CATEGORY*        1
# START*           1
# STOP*            1
# MILES*           0
# PURPOSE*       503
# dtype: int64

# %%
uber_data.iloc[0]
# Out:
# START_DATE*    1/1/2016 21:11
# END_DATE*      1/1/2016 21:17
# CATEGORY*            Business
# START*            Fort Pierce
# STOP*             Fort Pierce
# MILES*                    5.1
# PURPOSE*       Meal/Entertain
# Name: 0, dtype: object

# %%
uber_data.iloc[2:8]
# Out:
#       START_DATE*       END_DATE* CATEGORY*           START*            STOP*  \
# 2  1/2/2016 20:25  1/2/2016 20:38  Business      Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business      Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business      Fort Pierce  West Palm Beach
# 5  1/6/2016 17:15  1/6/2016 17:19  Business  West Palm Beach  West Palm Beach
# 6  1/6/2016 17:30  1/6/2016 17:35  Business  West Palm Beach       Palm Beach
# 7  1/7/2016 13:27  1/7/2016 13:33  Business             Cary             Cary
#
#    MILES*         PURPOSE*
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit
# 5     4.3   Meal/Entertain
# 6     7.1          Meeting
# 7     0.8          Meeting

# %%
uber_data.iloc[20:40]
# Out:
#         START_DATE*        END_DATE* CATEGORY*               START*  \
# 20  1/12/2016 15:13  1/12/2016 15:28  Business        Hudson Square
# 21  1/12/2016 15:42  1/12/2016 15:54  Business       Hell's Kitchen
# 22  1/12/2016 16:02  1/12/2016 17:00  Business             New York
# 23  1/13/2016 13:54  1/13/2016 14:07  Business             Downtown
# 24  1/13/2016 15:00  1/13/2016 15:28  Business              Gulfton
# 25  1/14/2016 16:29  1/14/2016 17:05  Business              Houston
# 26  1/14/2016 21:39  1/14/2016 21:45  Business           Eagan Park
# 27   1/15/2016 0:41   1/15/2016 1:01  Business          Morrisville
# 28  1/15/2016 11:43  1/15/2016 12:03  Business                 Cary
# 29  1/15/2016 13:26  1/15/2016 13:44  Business               Durham
# 30  1/18/2016 14:55  1/18/2016 15:06  Business                 Cary
# 31  1/18/2016 16:13  1/18/2016 16:24  Business     Farmington Woods
# 32   1/19/2016 9:09   1/19/2016 9:23  Business          Whitebridge
# ...

# %%
uber_data.iloc[20:40,1:3]
# Out:
#           END_DATE* CATEGORY*
# 20  1/12/2016 15:28  Business
# 21  1/12/2016 15:54  Business
# 22  1/12/2016 17:00  Business
# 23  1/13/2016 14:07  Business
# 24  1/13/2016 15:28  Business
# 25  1/14/2016 17:05  Business
# 26  1/14/2016 21:45  Business
# 27   1/15/2016 1:01  Business
# 28  1/15/2016 12:03  Business
# 29  1/15/2016 13:44  Business
# 30  1/18/2016 15:06  Business
# 31  1/18/2016 16:24  Business
# 32   1/19/2016 9:23  Business
# 33  1/19/2016 11:09  Business
# 34  1/20/2016 11:11  Business
# 35  1/20/2016 12:19  Business
# 36  1/20/2016 14:19  Business
# 37  1/21/2016 14:29  Business
# 38  1/21/2016 14:51  Business
# 39  1/21/2016 16:06  Business

# %%
uber_data.iloc[:,-1]
# Out:
# 0        Meal/Entertain
# 1                   NaN
# 2       Errand/Supplies
# 3               Meeting
# 4        Customer Visit
#              ...
# 1151     Temporary Site
# 1152            Meeting
# 1153     Temporary Site
# 1154     Temporary Site
# 1155                NaN
# Name: PURPOSE*, Length: 1156, dtype: object

# %%
# Read csv, excel and json file
#load only first 100 rows
#display first 5 rows and last two columns
#display all the rows from first 3 columns
#convert Object format to date format
#convert object to int, float formats.

# %%
uber_data.head(100)
# Out:
#         START_DATE*        END_DATE* CATEGORY*       START*            STOP*  \
# 0    1/1/2016 21:11   1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1     1/2/2016 1:25    1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2    1/2/2016 20:25   1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3    1/5/2016 17:31   1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4    1/6/2016 14:42   1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
# ..              ...              ...       ...          ...              ...
# 95   2/12/2016 8:21   2/12/2016 8:42  Business         Cary           Durham
# 96  2/12/2016 10:45  2/12/2016 10:52  Business       Durham      Morrisville
# 97  2/12/2016 11:14  2/12/2016 11:35  Business  Morrisville          Raleigh
# 98  2/12/2016 13:02  2/12/2016 13:36  Business      Raleigh             Cary
# 99  2/12/2016 14:49  2/12/2016 15:06  Business         Cary      Morrisville
#
#     MILES*         PURPOSE*
# ...

# %%
uber_data.iloc[1:6,1:3]
# Out:
#         END_DATE* CATEGORY*
# 1   1/2/2016 1:37  Business
# 2  1/2/2016 20:38  Business
# 3  1/5/2016 17:45  Business
# 4  1/6/2016 15:49  Business
# 5  1/6/2016 17:19  Business

# %%
uber_data.iloc[:,0:3]
# Out:
#            START_DATE*         END_DATE* CATEGORY*
# 0       1/1/2016 21:11    1/1/2016 21:17  Business
# 1        1/2/2016 1:25     1/2/2016 1:37  Business
# 2       1/2/2016 20:25    1/2/2016 20:38  Business
# 3       1/5/2016 17:31    1/5/2016 17:45  Business
# 4       1/6/2016 14:42    1/6/2016 15:49  Business
# ...                ...               ...       ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business
# 1155            Totals               NaN       NaN
#
# [1156 rows x 3 columns]

# %%
import pandas as pd
temp=pd.DataFrame({'A':[1,2,3,4],'B':[10,20,30,40],'C':['2025-1-19','2025-2-9','2025-4-7','2025-1-12']})
temp
# Out:
#    A   B          C
# 0  1  10  2025-1-19
# 1  2  20   2025-2-9
# 2  3  30   2025-4-7
# 3  4  40  2025-1-12

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       4 non-null      int64
#  1   B       4 non-null      int64
#  2   C       4 non-null      object
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
print(temp.dtypes)
# Out:
# A     int64
# B     int64
# C    object
# dtype: object

# %%
#conversion of data type from object to date format
temp['C']=pd.to_datetime(temp['C'])
temp.dtypes
# Out:
# A             int64
# B             int64
# C    datetime64[ns]
# dtype: object

# %%
temp
# Out:
#    A   B          C
# 0  1  10 2025-01-19
# 1  2  20 2025-02-09
# 2  3  30 2025-04-07
# 3  4  40 2025-01-12

# %%
temp1=pd.DataFrame({'A':[1,2,3,4],'B':[10,20,30,40],'C':['19/1/2025','9/2/2025','7/4/2025','10/1/2025']})
temp1
# Out:
#    A   B          C
# 0  1  10  19/1/2025
# 1  2  20   9/2/2025
# 2  3  30   7/4/2025
# 3  4  40  10/1/2025

# %%
temp1['C']=pd.to_datetime(temp1['C'])
temp1.dtypes
# Out:
# C:\Users\CVR\AppData\Local\Temp\ipykernel_11844\983465336.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   temp1['C']=pd.to_datetime(temp1['C'])
# A             int64
# B             int64
# C    datetime64[ns]
# dtype: object

# %%
#as we notice pandas takes default date in format yyyy-mm-dd hence it throws an error

# %%
temp1['C']=pd.to_datetime(temp1['C'],format="%d/%m/%y")
temp1.dtypes
# Out:
# A             int64
# B             int64
# C    datetime64[ns]
# dtype: object

# %%
#int to object(string)
temp1['A']=temp['A'].astype(str)
temp1.dtypes
# Out:
# A            object
# B             int64
# C    datetime64[ns]
# dtype: object

# %%
uber_data
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
df=uber_data['START*'].nunique()
df
# Out:
# 177

# %%
#finding the unique cities along with the number of times its being repeated
uber_data['START*'].value_counts()
# Out:
# START*
# Cary                201
# Unknown Location    148
# Morrisville          85
# Whitebridge          68
# Islamabad            57
#                    ...
# Florence              1
# Ridgeland             1
# Daytona Beach         1
# Sky Lake              1
# Gampaha               1
# Name: count, Length: 177, dtype: int64

# %%
a=uber_data[(uber_data['MILES*']>50)&(uber_data['MILES*']<100)]

# %%
#printing a few columns only
a.iloc[:,3:6]
# Out:
#        START*             STOP*  MILES*
# 10   New York            Queens    10.8
# 22   New York     Queens County    15.1
# 106  New York  Long Island City    13.0
# 423  New York           Jamaica    16.3

# %%
a=uber_data[(uber_data['START*']=="New York")]
a
# Out:
#          START_DATE*        END_DATE* CATEGORY*    START*             STOP*  \
# 10   1/10/2016 15:08  1/10/2016 15:51  Business  New York            Queens
# 22   1/12/2016 16:02  1/12/2016 17:00  Business  New York     Queens County
# 106  2/14/2016 16:35  2/14/2016 17:02  Business  New York  Long Island City
# 423  6/10/2016 15:19  6/10/2016 16:28  Business  New York           Jamaica
#
#      MILES* PURPOSE*
# 10     10.8  Meeting
# 22     15.1  Meeting
# 106    13.0  Meeting
# 423    16.3  Meeting

# %%
#printing particualr cities in a single line instead of using conditional statements,OR operator
uber_data.loc[uber_data['START*'].isin(['New York','Cary'])]
# Out:
#            START_DATE*         END_DATE* CATEGORY*    START*          STOP*  \
# 7       1/7/2016 13:27    1/7/2016 13:33  Business      Cary           Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business      Cary    Morrisville
# 10     1/10/2016 15:08   1/10/2016 15:51  Business  New York         Queens
# 22     1/12/2016 16:02   1/12/2016 17:00  Business  New York  Queens County
# 28     1/15/2016 11:43   1/15/2016 12:03  Business      Cary         Durham
# ...                ...               ...       ...       ...            ...
# 1049  12/13/2016 20:20  12/13/2016 20:29  Business      Cary           Cary
# 1050  12/14/2016 16:52  12/14/2016 17:10  Business      Cary           Cary
# 1051  12/14/2016 17:22  12/14/2016 17:34  Business      Cary           Cary
# 1052  12/14/2016 17:50  12/14/2016 18:00  Business      Cary    Morrisville
# 1054  12/15/2016 14:20  12/15/2016 14:54  Business      Cary    Morrisville
#
#       MILES*        PURPOSE*
# ...

# %%
#display all the records whose start city is New York or Cary and Stop city is Queens or Raleigh and miles between 10 to  20
df=uber_data.loc[uber_data['START*'].isin(['New York','Cary'])&(uber_data['STOP*'].isin(['Queens','Raleigh']))&(uber_data['MILES*']>10)&(uber_data['MILES*']<20)]
# Out:
#             START_DATE*        END_DATE* CATEGORY*    START*    STOP*  MILES*  \
# 10  2016-01-10 15:08:00  1/10/2016 15:51  Business  New York   Queens    10.8
# 34  2016-01-20 10:36:00  1/20/2016 11:11  Business      Cary  Raleigh    17.1
# 46  2016-01-27 10:19:00  1/27/2016 10:48  Business      Cary  Raleigh    18.7
# 50  2016-01-28 12:28:00  1/28/2016 13:00  Business      Cary  Raleigh    19.0
# 76  2016-02-06 16:20:00   2/6/2016 16:53  Business      Cary  Raleigh    11.4
# 91  2016-02-11 16:28:00  2/11/2016 17:10  Business      Cary  Raleigh    17.3
# 187 2016-03-04 13:40:00   3/4/2016 14:09  Business      Cary  Raleigh    15.7
# 200 2016-03-07 09:23:00    3/7/2016 9:47  Business      Cary  Raleigh    12.4
# 307 2016-04-08 14:43:00   4/8/2016 15:20  Business      Cary  Raleigh    19.1
# 316 2016-04-15 11:36:00  4/15/2016 12:07  Business      Cary  Raleigh    11.9
#
#             PURPOSE*
# 10           Meeting
# 34           Meeting
# 46    Customer Visit
# 50    Temporary Site
# ...

# %%
uber_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1156 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
#convert START_DATE Object datatype to datetime datatype
uber_data['START_DATE*']=pd.to_datetime(uber_data['START_DATE*'], format="%m/%d/%Y %H:%M",errors='coerce')

# %%
uber_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1155 non-null   datetime64[ns]
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(5)
# memory usage: 63.3+ KB

# %%
#display all the records of Jan
uber_data[(uber_data['START_DATE*'].apply(lambda x: x.month == 1 if pd.notnull(x) else False))]
# Out:
#            START_DATE*        END_DATE* CATEGORY*       START*  \
# 0  2016-01-01 21:11:00   1/1/2016 21:17  Business  Fort Pierce
# 1  2016-01-02 01:25:00    1/2/2016 1:37  Business  Fort Pierce
# 2  2016-01-02 20:25:00   1/2/2016 20:38  Business  Fort Pierce
# 3  2016-01-05 17:31:00   1/5/2016 17:45  Business  Fort Pierce
# 4  2016-01-06 14:42:00   1/6/2016 15:49  Business  Fort Pierce
# ..                 ...              ...       ...          ...
# 56 2016-01-29 13:24:00  1/29/2016 13:47  Business       Durham
# 57 2016-01-29 18:31:00  1/29/2016 18:52  Business         Cary
# 58 2016-01-29 21:21:00  1/29/2016 21:40  Business         Apex
# 59 2016-01-30 16:21:00  1/30/2016 16:33  Business         Cary
# 60 2016-01-30 18:09:00  1/30/2016 18:24  Business         Apex
#
#               STOP*  MILES*         PURPOSE*
# 0       Fort Pierce     5.1   Meal/Entertain
# 1       Fort Pierce     5.0              NaN
# 2       Fort Pierce     4.8  Errand/Supplies
# ...

# %%
#display all the records of Jan-2016
df = uber_data[(uber_data['START_DATE*'].dt.month == 2) & (uber_data['START_DATE*'].dt.year == 2016)]
print(df)
# Out:
#             START_DATE*        END_DATE* CATEGORY*       START*  \
# 61  2016-02-01 10:35:00   2/1/2016 11:15  Business         Cary
# 62  2016-02-01 12:10:00   2/1/2016 12:43  Business  Chapel Hill
# 63  2016-02-01 12:56:00   2/1/2016 13:07  Business   Northwoods
# 64  2016-02-02 13:04:00   2/2/2016 13:23  Business  Whitebridge
# 65  2016-02-02 13:51:00   2/2/2016 14:06  Business         Cary
# ..                  ...              ...       ...          ...
# 171 2016-02-29 11:07:00  2/29/2016 11:14  Personal  Whitebridge
# 172 2016-02-29 11:30:00  2/29/2016 11:40  Business         Cary
# 173 2016-02-29 12:36:00  2/29/2016 12:48  Business         Apex
# 174 2016-02-29 14:55:00  2/29/2016 15:03  Business  Whitebridge
# 175 2016-02-29 16:40:00  2/29/2016 17:00  Business    Hazelwood
#
#                   STOP*  MILES*         PURPOSE*
# 61          Chapel Hill    19.4   Customer Visit
# 62                 Cary    23.3   Customer Visit
# ...

# %%
#display all the reocrds of jan-2016 and start city=Cary
df = uber_data[(uber_data['START_DATE*'].dt.month == 1) & (uber_data['START_DATE*'].dt.year == 2016) & (uber_data['START*']=="Cary")]
print(df)
# Out:
#            START_DATE*        END_DATE* CATEGORY* START*        STOP*  MILES*  \
# 7  2016-01-07 13:27:00   1/7/2016 13:33  Business   Cary         Cary     0.8
# 8  2016-01-10 08:05:00   1/10/2016 8:25  Business   Cary  Morrisville     8.3
# 28 2016-01-15 11:43:00  1/15/2016 12:03  Business   Cary       Durham    10.4
# 30 2016-01-18 14:55:00  1/18/2016 15:06  Business   Cary         Cary     4.8
# 34 2016-01-20 10:36:00  1/20/2016 11:11  Business   Cary      Raleigh    17.1
# 37 2016-01-21 14:25:00  1/21/2016 14:29  Business   Cary         Cary     1.6
# 38 2016-01-21 14:43:00  1/21/2016 14:51  Business   Cary         Cary     2.4
# 39 2016-01-21 16:01:00  1/21/2016 16:06  Business   Cary         Cary     1.0
# 43 2016-01-26 17:17:00  1/26/2016 17:22  Business   Cary         Cary     1.4
# 44 2016-01-26 17:27:00  1/26/2016 17:29  Business   Cary         Cary     0.5
# 45 2016-01-27 09:24:00   1/27/2016 9:31  Business   Cary         Cary     1.8
# ...

# %%
#resetting the index of the filtered data(SNo. starting with-1)
df=uber_data.loc[uber_data['START*'].isin(['New York','Cary'])&(uber_data['STOP*'].isin(['Queens','Raleigh']))&(uber_data['MILES*']>10)&(uber_data['MILES*']<20)]
df.reset_index(inplace=True,drop=True)

# %%
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*    START*    STOP*  MILES*  \
# 0  2016-01-10 15:08:00   1/10/2016 15:51  Business  New York   Queens    10.8
# 1  2016-01-20 10:36:00   1/20/2016 11:11  Business      Cary  Raleigh    17.1
# 2  2016-01-27 10:19:00   1/27/2016 10:48  Business      Cary  Raleigh    18.7
# 3  2016-01-28 12:28:00   1/28/2016 13:00  Business      Cary  Raleigh    19.0
# 4  2016-02-06 16:20:00    2/6/2016 16:53  Business      Cary  Raleigh    11.4
# 5  2016-02-11 16:28:00   2/11/2016 17:10  Business      Cary  Raleigh    17.3
# 6  2016-03-04 13:40:00    3/4/2016 14:09  Business      Cary  Raleigh    15.7
# 7  2016-03-07 09:23:00     3/7/2016 9:47  Business      Cary  Raleigh    12.4
# 8  2016-04-08 14:43:00    4/8/2016 15:20  Business      Cary  Raleigh    19.1
# 9  2016-04-15 11:36:00   4/15/2016 12:07  Business      Cary  Raleigh    11.9
# 10 2016-04-22 08:25:00    4/22/2016 9:04  Business      Cary  Raleigh    13.6
# ...

# %%
#sorting 
uber_data.sort_values(by='MILES*',ascending=False)
#asceding=false gives a descending order
# Out:
#              START_DATE*         END_DATE* CATEGORY*            START*  \
# 1155                 NaT               NaN       NaN               NaN
# 269  2016-03-25 16:52:00   3/25/2016 22:22  Business             Latta
# 270  2016-03-25 22:54:00    3/26/2016 1:39  Business      Jacksonville
# 881  2016-10-30 15:22:00  10/30/2016 18:23  Business         Asheville
# 776  2016-09-27 21:01:00    9/28/2016 2:37  Business  Unknown Location
# ...                  ...               ...       ...               ...
# 1121 2016-12-27 12:53:00  12/27/2016 12:57  Business           Kar?chi
# 1110 2016-12-24 22:04:00  12/24/2016 22:09  Business            Lahore
# 44   2016-01-26 17:27:00   1/26/2016 17:29  Business              Cary
# 420  2016-06-08 17:16:00    6/8/2016 17:18  Business              Soho
# 120  2016-02-17 16:38:00   2/17/2016 16:43  Business        Katunayaka
#
#                  STOP*   MILES*         PURPOSE*
# 1155               NaN  12204.7              NaN
# ...

# %%
uber_data.sort_values(by='START*',ascending=False)
#it works with strings also
# Out:
#              START_DATE*         END_DATE* CATEGORY*         START*  \
# 870  2016-10-28 18:13:00  10/28/2016 20:07  Business  Winston Salem
# 648  2016-08-11 12:53:00   8/11/2016 13:00  Business    Whitebridge
# 72   2016-02-04 18:04:00    2/4/2016 18:31  Business    Whitebridge
# 889  2016-11-01 17:35:00   11/1/2016 17:42  Business    Whitebridge
# 459  2016-06-24 10:41:00   6/24/2016 10:57  Business    Whitebridge
# ...                  ...               ...       ...            ...
# 906  2016-11-04 21:04:00   11/4/2016 21:20  Business          Agnew
# 911  2016-11-06 10:50:00   11/6/2016 11:04  Business          Agnew
# 910  2016-11-05 19:20:00   11/5/2016 19:28  Business          Agnew
# 908  2016-11-05 08:34:00    11/5/2016 8:43  Business          Agnew
# 1155                 NaT               NaN       NaN            NaN
#
#                 STOP*   MILES*        PURPOSE*
# 870         Asheville    133.6         Meeting
# 648    Heritage Pines      2.2             NaN
# ...

# %%
uber_data.sort_values(by=['START*','MILES*'],ascending=[True,False])
#two conditions- start-ac;miles-dc////here city agnew with highest miles record is printed moving in descending order and the same is repeated for the next country
# Out:
#              START_DATE*         END_DATE* CATEGORY*         START*  \
# 906  2016-11-04 21:04:00   11/4/2016 21:20  Business          Agnew
# 911  2016-11-06 10:50:00   11/6/2016 11:04  Business          Agnew
# 908  2016-11-05 08:34:00    11/5/2016 8:43  Business          Agnew
# 910  2016-11-05 19:20:00   11/5/2016 19:28  Business          Agnew
# 879  2016-10-30 12:58:00  10/30/2016 13:18  Business         Almond
# ...                  ...               ...       ...            ...
# 889  2016-11-01 17:35:00   11/1/2016 17:42  Business    Whitebridge
# 890  2016-11-01 19:14:00   11/1/2016 19:20  Business    Whitebridge
# 516  2016-07-05 16:48:00    7/5/2016 16:52  Business    Whitebridge
# 870  2016-10-28 18:13:00  10/28/2016 20:07  Business  Winston Salem
# 1155                 NaT               NaN       NaN            NaN
#
#             STOP*   MILES*         PURPOSE*
# 906          Cory      4.3              NaN
# 911   Renaissance      2.4              NaN
# ...

# %%
#understanding numpy
import numpy as np
uber_data["MILES_CAT"]=np.where(uber_data['MILES*']>100,"Long Trip","Short Trip")
#where clause
uber_data
# Out:
#              START_DATE*         END_DATE* CATEGORY*            START*  \
# 0    2016-01-01 21:11:00    1/1/2016 21:17  Business       Fort Pierce
# 1    2016-01-02 01:25:00     1/2/2016 1:37  Business       Fort Pierce
# 2    2016-01-02 20:25:00    1/2/2016 20:38  Business       Fort Pierce
# 3    2016-01-05 17:31:00    1/5/2016 17:45  Business       Fort Pierce
# 4    2016-01-06 14:42:00    1/6/2016 15:49  Business       Fort Pierce
# ...                  ...               ...       ...               ...
# 1151 2016-12-31 13:24:00  12/31/2016 13:42  Business           Kar?chi
# 1152 2016-12-31 15:03:00  12/31/2016 15:38  Business  Unknown Location
# 1153 2016-12-31 21:32:00  12/31/2016 21:50  Business        Katunayake
# 1154 2016-12-31 22:08:00  12/31/2016 23:51  Business           Gampaha
# 1155                 NaT               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*   MILES_CAT
# ...

# %%
uber_data['MILES_CAT2'] = np.where(uber_data['MILES*'] < 100, 'Short Trip', np.where(uber_data['MILES*'] <= 200, 'Medium Trip', 'Long Trip'))
uber_data.iloc[450:780]
#where clause with three conditions, if the cond is false moves to false result with another condition(2nd where clause)
# Out:
#             START_DATE*        END_DATE* CATEGORY*            START*  \
# 450 2016-06-16 15:17:00  6/16/2016 15:41  Business            Kenner
# 451 2016-06-16 19:39:00  6/16/2016 19:56  Business       New Orleans
# 452 2016-06-16 21:43:00  6/16/2016 21:56  Business            Kenner
# 453 2016-06-17 16:11:00  6/17/2016 16:44  Business       New Orleans
# 454 2016-06-18 00:29:00   6/18/2016 0:51  Business       Morrisville
# ..                  ...              ...       ...               ...
# 775 2016-09-27 19:14:00  9/27/2016 20:34  Business            Lahore
# 776 2016-09-27 21:01:00   9/28/2016 2:37  Business  Unknown Location
# 777 2016-09-28 17:21:00  9/28/2016 19:36  Business         Islamabad
# 778 2016-09-29 16:13:00  9/29/2016 18:47  Business  Unknown Location
# 779 2016-09-30 17:39:00  9/30/2016 20:20  Business         Islamabad
#
#                 STOP*  MILES* PURPOSE*   MILES_CAT   MILES_CAT2
# 450       New Orleans    15.0      NaN  Short Trip   Short Trip
# ...

# %%
conditions=[(uber_data['MILES*']<100),(uber_data["MILES*"]>=100)&(uber_data['MILES*']<=200),(uber_data['MILES*']>=200)]
cat=["Short trip","Medium Trip","Long Trip"]
uber_data["MILES_CAT3"]=np.select(conditions,cat,default="Unknown")
#more then one condition statements

# %%
uber_data
# Out:
#              START_DATE*         END_DATE* CATEGORY*            START*  \
# 0    2016-01-01 21:11:00    1/1/2016 21:17  Business       Fort Pierce
# 1    2016-01-02 01:25:00     1/2/2016 1:37  Business       Fort Pierce
# 2    2016-01-02 20:25:00    1/2/2016 20:38  Business       Fort Pierce
# 3    2016-01-05 17:31:00    1/5/2016 17:45  Business       Fort Pierce
# 4    2016-01-06 14:42:00    1/6/2016 15:49  Business       Fort Pierce
# ...                  ...               ...       ...               ...
# 1151 2016-12-31 13:24:00  12/31/2016 13:42  Business           Kar?chi
# 1152 2016-12-31 15:03:00  12/31/2016 15:38  Business  Unknown Location
# 1153 2016-12-31 21:32:00  12/31/2016 21:50  Business        Katunayake
# 1154 2016-12-31 22:08:00  12/31/2016 23:51  Business           Gampaha
# 1155                 NaT               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*   MILES_CAT  MILES_CAT2  \
# ...

# %%
uber_data.groupby('MILES_CAT3').count()
# Out:
#              START_DATE*  END_DATE*  CATEGORY*  START*  STOP*  MILES*  \
# MILES_CAT3
# Long Trip              2          2          2       2      2       3
# Medium Trip           14         14         14      14     14      14
# Short trip          1139       1139       1139    1139   1139    1139
#
#              PURPOSE*  MILES_CAT  MILES_CAT2
# MILES_CAT3
# Long Trip           2          3           3
# Medium Trip         9         14          14
# Short trip        642       1139        1139

# %%
uber_data['MILES_CAT3'].value_counts()
# Out:
# MILES_CAT3
# Short trip     1139
# Medium Trip      14
# Long Trip         3
# Name: count, dtype: int64

# %%
uber_data.groupby('PURPOSE*')['MILES*'].agg('mean')
# Out:
# PURPOSE*
# Airport/Travel       5.500000
# Between Offices     10.944444
# Charity ($)         15.100000
# Commute            180.200000
# Customer Visit      20.688119
# Errand/Supplies      3.968750
# Meal/Entertain       5.698125
# Meeting             15.247594
# Moving               4.550000
# Temporary Site      10.474000
# Name: MILES*, dtype: float64
