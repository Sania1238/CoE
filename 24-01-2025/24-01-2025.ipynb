# %%
import pandas as pd
df=pd.read_csv("fashion_products.csv")
df
# Out:
#      User ID  Product ID Product Name   Brand         Category  Price  \
# 0         19           1        Dress  Adidas    Men's Fashion     40
# 1         97           2        Shoes     H&M  Women's Fashion     82
# 2         25           3        Dress  Adidas  Women's Fashion     44
# 3         57           4        Shoes    Zara    Men's Fashion     23
# 4         79           5      T-shirt  Adidas    Men's Fashion     79
# ..       ...         ...          ...     ...              ...    ...
# 995       20         996        Shoes    Zara  Women's Fashion     55
# 996       42         997      Sweater    Nike    Kids' Fashion     13
# 997        9         998      Sweater    Zara    Men's Fashion     47
# 998        8         999      T-shirt    Zara  Women's Fashion     68
# 999       91        1000        Shoes  Adidas  Women's Fashion     79
#
#        Rating   Color Size
# 0    1.043159   Black   XL
# 1    4.026416   Black    L
# 2    3.337938  Yellow   XL
# ...

# %%
import numpy as np
df.head(5)
# Out:
#    User ID  Product ID Product Name   Brand         Category  Price    Rating  \
# 0       19           1        Dress  Adidas    Men's Fashion     40  1.043159
# 1       97           2        Shoes     H&M  Women's Fashion     82  4.026416
# 2       25           3        Dress  Adidas  Women's Fashion     44  3.337938
# 3       57           4        Shoes    Zara    Men's Fashion     23  1.049523
# 4       79           5      T-shirt  Adidas    Men's Fashion     79  4.302773
#
#     Color Size
# 0   Black   XL
# 1   Black    L
# 2  Yellow   XL
# 3   White    S
# 4   Black    M

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   User ID       1000 non-null   int64
#  1   Product ID    1000 non-null   int64
#  2   Product Name  1000 non-null   object
#  3   Brand         1000 non-null   object
#  4   Category      1000 non-null   object
#  5   Price         1000 non-null   int64
#  6   Rating        1000 non-null   float64
#  7   Color         1000 non-null   object
#  8   Size          1000 non-null   object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 70.4+ KB

# %%
df.shape
# Out:
# (1000, 9)

# %%
df.isnull().sum()
# Out:
# User ID         0
# Product ID      0
# Product Name    0
# Brand           0
# Category        0
# Price           0
# Rating          0
# Color           0
# Size            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['User ID', 'Product ID', 'Product Name', 'Brand', 'Category', 'Price',
#        'Rating', 'Color', 'Size'],
#       dtype='object')

# %%
df.iloc[2:600,2:6]
# Out:
#     Product Name   Brand         Category  Price
# 2          Dress  Adidas  Women's Fashion     44
# 3          Shoes    Zara    Men's Fashion     23
# 4        T-shirt  Adidas    Men's Fashion     79
# 5          Dress  Adidas    Men's Fashion     47
# 6          Jeans   Gucci    Men's Fashion     37
# ..           ...     ...              ...    ...
# 595        Dress     H&M  Women's Fashion     35
# 596        Jeans     H&M    Men's Fashion     38
# 597        Shoes   Gucci  Women's Fashion     77
# 598      T-shirt     H&M    Men's Fashion     80
# 599      T-shirt  Adidas    Men's Fashion     97
#
# [598 rows x 4 columns]

# %%
df["Brand"]
# Out:
# 0      Adidas
# 1         H&M
# 2      Adidas
# 3        Zara
# 4      Adidas
#         ...
# 995      Zara
# 996      Nike
# 997      Zara
# 998      Zara
# 999    Adidas
# Name: Brand, Length: 1000, dtype: object

# %%
df["Brand"].unique()
# Out:
# array(['Adidas', 'H&M', 'Zara', 'Gucci', 'Nike'], dtype=object)

# %%
df["Brand"].nunique()
# Out:
# 5

# %%
a=df.drop_duplicates()
a
# Out:
#      User ID  Product ID Product Name   Brand         Category  Price  \
# 0         19           1        Dress  Adidas    Men's Fashion     40
# 1         97           2        Shoes     H&M  Women's Fashion     82
# 2         25           3        Dress  Adidas  Women's Fashion     44
# 3         57           4        Shoes    Zara    Men's Fashion     23
# 4         79           5      T-shirt  Adidas    Men's Fashion     79
# ..       ...         ...          ...     ...              ...    ...
# 995       20         996        Shoes    Zara  Women's Fashion     55
# 996       42         997      Sweater    Nike    Kids' Fashion     13
# 997        9         998      Sweater    Zara    Men's Fashion     47
# 998        8         999      T-shirt    Zara  Women's Fashion     68
# 999       91        1000        Shoes  Adidas  Women's Fashion     79
#
#        Rating   Color Size
# 0    1.043159   Black   XL
# 1    4.026416   Black    L
# 2    3.337938  Yellow   XL
# ...

# %%
df.describe()
#min and max help identify the outlayers (outlayers are identified using boxplot)
#
# Out:
#           User ID   Product ID        Price       Rating
# count  1000.00000  1000.000000  1000.000000  1000.000000
# mean     50.41900   500.500000    55.785000     2.993135
# std      28.78131   288.819436    26.291748     1.153185
# min       1.00000     1.000000    10.000000     1.000967
# 25%      26.00000   250.750000    33.000000     1.992786
# 50%      50.00000   500.500000    57.000000     2.984003
# 75%      75.00000   750.250000    78.250000     3.985084
# max     100.00000  1000.000000   100.000000     4.987964

# %%
import matplotlib.pyplot as plt
plt.boxplot(df["Price"])
plt.show()

# %%
#statistics
df['Price'].mean()
# Out:
# 55.785

# %%
df['Price'].median()
# Out:
# 57.0

# %%
df['Price'].mode()
# Out:
# 0    55
# 1    68
# 2    80
# 3    96
# Name: Price, dtype: int64

# %%
df['Price'].std()
#standard deviation
# Out:
# 26.29174834489009

# %%
df['Price'].corr(df['Product ID'])
#corr cannot be used on columns with string datatype
# Out:
# 0.0346022129048948

# %%
df.dropna()
# Out:
#      User ID  Product ID Product Name   Brand         Category  Price  \
# 0         19           1        Dress  Adidas    Men's Fashion     40
# 1         97           2        Shoes     H&M  Women's Fashion     82
# 2         25           3        Dress  Adidas  Women's Fashion     44
# 3         57           4        Shoes    Zara    Men's Fashion     23
# 4         79           5      T-shirt  Adidas    Men's Fashion     79
# ..       ...         ...          ...     ...              ...    ...
# 995       20         996        Shoes    Zara  Women's Fashion     55
# 996       42         997      Sweater    Nike    Kids' Fashion     13
# 997        9         998      Sweater    Zara    Men's Fashion     47
# 998        8         999      T-shirt    Zara  Women's Fashion     68
# 999       91        1000        Shoes  Adidas  Women's Fashion     79
#
#        Rating   Color Size
# 0    1.043159   Black   XL
# 1    4.026416   Black    L
# 2    3.337938  Yellow   XL
# ...

# %%
df.T
# Out:
#                         0                1                2              3    \
# User ID                  19               97               25             57
# Product ID                1                2                3              4
# Product Name          Dress            Shoes            Dress          Shoes
# Brand                Adidas              H&M           Adidas           Zara
# Category      Men's Fashion  Women's Fashion  Women's Fashion  Men's Fashion
# Price                    40               82               44             23
# Rating             1.043159         4.026416         3.337938       1.049523
# Color                 Black            Black           Yellow          White
# Size                     XL                L               XL              S
#
#                         4              5              6              7    \
# User ID                  79             98             16             63
# ...

# %%
df
# Out:
#      User ID  Product ID Product Name   Brand         Category  Price  \
# 0         19           1        Dress  Adidas    Men's Fashion     40
# 1         97           2        Shoes     H&M  Women's Fashion     82
# 2         25           3        Dress  Adidas  Women's Fashion     44
# 3         57           4        Shoes    Zara    Men's Fashion     23
# 4         79           5      T-shirt  Adidas    Men's Fashion     79
# ..       ...         ...          ...     ...              ...    ...
# 995       20         996        Shoes    Zara  Women's Fashion     55
# 996       42         997      Sweater    Nike    Kids' Fashion     13
# 997        9         998      Sweater    Zara    Men's Fashion     47
# 998        8         999      T-shirt    Zara  Women's Fashion     68
# 999       91        1000        Shoes  Adidas  Women's Fashion     79
#
#        Rating   Color Size
# 0    1.043159   Black   XL
# 1    4.026416   Black    L
# 2    3.337938  Yellow   XL
# ...

# %%
df.sort_values(by="User ID",ascending=False)
# Out:
#      User ID  Product ID Product Name  Brand         Category  Price  \
# 958      100         959      Sweater    H&M    Kids' Fashion     45
# 396      100         397        Shoes   Zara    Kids' Fashion     94
# 805      100         806        Jeans   Zara  Women's Fashion     11
# 476      100         477      Sweater   Nike    Men's Fashion     30
# 81       100          82        Dress    H&M    Kids' Fashion     31
# ..       ...         ...          ...    ...              ...    ...
# 963        1         964        Dress   Nike  Women's Fashion     31
# 464        1         465      T-shirt  Gucci  Women's Fashion     17
# 478        1         479      Sweater   Nike    Men's Fashion     51
# 514        1         515        Dress   Nike    Kids' Fashion     64
# 878        1         879      T-shirt   Nike    Kids' Fashion     67
#
#        Rating   Color Size
# 958  2.565573  Yellow   XL
# 396  1.573943   White   XL
# 805  3.778631   Green    L
# ...
